# %%
import numpy as np
from matplotlib.pyplot import *

# %%
data = np.load('../data/pilot_1.npy')

# %%
fig, ax = subplots(nrows=1, ncols=1, figsize=(6,6))
ax.imshow(data, cmap="hot")

# %%
data = np.load('../data/pilot_2.npy')

# %%
fig, ax = subplots(nrows=1, ncols=1, figsize=(6,6))
ax.imshow(data, cmap="hot")
